# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split, DataLoader
from torchvision import datasets, transforms, models
import pandas as pd
import os
import numpy as np

# %%
# load the training-set
batch_size = 64

transform_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(root='../cs-424-ass-1-wednesday-class/train', transform=transform_train)

# Split dataset into training and validation sets (e.g., 80% train, 20% validation)
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Define ResNet-18 
class CustomResNet18(nn.Module):
    def __init__(self, num_classes):
        super(CustomResNet18, self).__init__()

        self.model = models.resnet18(weights=None)
        self.model.fc = nn.Sequential(
            nn.Linear(self.model.fc.in_features, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.model(x)



num_classes = 10   
model = CustomResNet18(num_classes=num_classes).to(dev)

# Define the loss function and optimizer
learning_rate = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Function for random augmentations that change each epoch
def get_random_transform():
    return transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
        transforms.RandomAffine(degrees=15, translate=(0.1, 0.1)),
        transforms.RandomPerspective(distortion_scale=0.2, p=0.5, interpolation=3),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# Mixup function implementation
def mixup_data(x, y, alpha=0.4):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.0
    batch_size = x.size(0)
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

# Modified train function with mixup and random augmentations
def train_model():
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        total_correct = 0
        total_samples = 0
        
        # Reinitialize augmentations for each epoch
        transform_train = get_random_transform()
        train_dataset = datasets.ImageFolder(root='../cs-424-ass-1-wednesday-class/train', transform=transform_train)
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

        for images, labels in train_loader:
            images, labels = images.to(dev), labels.to(dev)

            # Apply Mixup
            mixed_images, targets_a, targets_b, lam = mixup_data(images, labels)

            outputs = model(mixed_images)
            loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            total_samples += images.size(0)
            _, predicted = torch.max(outputs, 1)
            total_correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
        
        train_loss = total_loss / len(train_loader)
        train_accuracy = total_correct / total_samples


        model.eval()
        total_val_loss = 0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(dev), labels.to(dev)
                
                # Apply augmentations to the validation set
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                total_val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_loss = total_val_loss / len(val_loader)
        val_accuracy = correct_val / total_val

        # Print loss and accuracy for both training and validation
        print(f"Epoch [{epoch+1}/{num_epochs}], "
              f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

    # Save the model
    torch.save(model.state_dict(), 'resnet18_local.pth')

# %%
if __name__ == "__main__":
    num_epochs = 200
    train_model()
# Out:
# Epoch [1/200], Train Loss: 2.0676, Train Accuracy: 0.2477, Val Loss: 2.2426, Val Accuracy: 0.2393
# Epoch [2/200], Train Loss: 2.2351, Train Accuracy: 0.1753, Val Loss: 1.9981, Val Accuracy: 0.2286
# Epoch [3/200], Train Loss: 2.0868, Train Accuracy: 0.2222, Val Loss: 1.9781, Val Accuracy: 0.2464
# Epoch [4/200], Train Loss: 2.0547, Train Accuracy: 0.2196, Val Loss: 1.9074, Val Accuracy: 0.2500
# Epoch [5/200], Train Loss: 2.0210, Train Accuracy: 0.2197, Val Loss: 1.8556, Val Accuracy: 0.3250
# Epoch [6/200], Train Loss: 2.0065, Train Accuracy: 0.2453, Val Loss: 1.8331, Val Accuracy: 0.2786
# Epoch [7/200], Train Loss: 1.9168, Train Accuracy: 0.2729, Val Loss: 1.7856, Val Accuracy: 0.3250
# Epoch [8/200], Train Loss: 1.9742, Train Accuracy: 0.2641, Val Loss: 1.7026, Val Accuracy: 0.3607
# Epoch [9/200], Train Loss: 1.9069, Train Accuracy: 0.3027, Val Loss: 1.8134, Val Accuracy: 0.3607
# Epoch [10/200], Train Loss: 1.8903, Train Accuracy: 0.3199, Val Loss: 1.7616, Val Accuracy: 0.3357
# Epoch [11/200], Train Loss: 1.8470, Train Accuracy: 0.3247, Val Loss: 1.6951, Val Accuracy: 0.3821
# Epoch [12/200], Train Loss: 1.8128, Train Accuracy: 0.3455, Val Loss: 1.6246, Val Accuracy: 0.3607
# Epoch [13/200], Train Loss: 1.8411, Train Accuracy: 0.3182, Val Loss: 1.6017, Val Accuracy: 0.3429
# Epoch [14/200], Train Loss: 1.7992, Train Accuracy: 0.3399, Val Loss: 1.5303, Val Accuracy: 0.4107
# Epoch [15/200], Train Loss: 1.7916, Train Accuracy: 0.3505, Val Loss: 1.5060, Val Accuracy: 0.4286
# Epoch [16/200], Train Loss: 1.7426, Train Accuracy: 0.3686, Val Loss: 1.6928, Val Accuracy: 0.4000
# Epoch [17/200], Train Loss: 1.7514, Train Accuracy: 0.3503, Val Loss: 1.4866, Val Accuracy: 0.4321
# Epoch [186/200], Train Loss: 0.5324, Train Accuracy: 0.8794, Val Loss: 0.1040, Val Accuracy: 0.9714
# Epoch [187/200], Train Loss: 0.5919, Train Accuracy: 0.8468, Val Loss: 0.1665, Val Accuracy: 0.9750
# Epoch [188/200], Train Loss: 0.4204, Train Accuracy: 0.9071, Val Loss: 0.0805, Val Accuracy: 0.9857
# Epoch [189/200], Train Loss: 0.6005, Train Accuracy: 0.8528, Val Loss: 0.0948, Val Accuracy: 0.9821
# Epoch [190/200], Train Loss: 0.5753, Train Accuracy: 0.8455, Val Loss: 0.1085, Val Accuracy: 0.9714
# Epoch [191/200], Train Loss: 0.6515, Train Accuracy: 0.8337, Val Loss: 0.0760, Val Accuracy: 0.9750
# Epoch [192/200], Train Loss: 0.4842, Train Accuracy: 0.8866, Val Loss: 0.1081, Val Accuracy: 0.9893
# Epoch [193/200], Train Loss: 0.6195, Train Accuracy: 0.8527, Val Loss: 0.0639, Val Accuracy: 0.9964
# Epoch [194/200], Train Loss: 0.5559, Train Accuracy: 0.8691, Val Loss: 0.0732, Val Accuracy: 0.9857
# Epoch [195/200], Train Loss: 0.6515, Train Accuracy: 0.8271, Val Loss: 0.0655, Val Accuracy: 0.9821
# Epoch [196/200], Train Loss: 0.4880, Train Accuracy: 0.8838, Val Loss: 0.0980, Val Accuracy: 0.9821
# Epoch [197/200], Train Loss: 0.5703, Train Accuracy: 0.8662, Val Loss: 0.0976, Val Accuracy: 0.9857
# Epoch [198/200], Train Loss: 0.3651, Train Accuracy: 0.9283, Val Loss: 0.0664, Val Accuracy: 0.9821
# Epoch [199/200], Train Loss: 0.4870, Train Accuracy: 0.8969, Val Loss: 0.0990, Val Accuracy: 0.9857
# Epoch [200/200], Train Loss: 0.5652, Train Accuracy: 0.8641, Val Loss: 0.1692, Val Accuracy: 0.9607

# %%
# Model size (should be less than 26)

total_params = sum(p.numel() for p in model.parameters())
total_params/(1024*1024)
# Out:
# 10.914133071899414

# %%
# load the test-set
transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


test_dataset = datasets.ImageFolder(root='../cs-424-ass-1-wednesday-class/test', transform=transform_test)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
# test the model
def test_model():
    model.eval()
    predictions = []
    image_paths = [path for path, _ in test_dataset.imgs]   

    old_prefix = ".."
    new_prefix = "/kaggle/input"
    
    with torch.no_grad():
        for images, _ in test_loader:   
            images = images.to(dev)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            predictions.extend(predicted.cpu().numpy())

    adjusted_paths= [path.replace(old_prefix, new_prefix) for path in image_paths]
    final_paths= [path.replace("\\", "/") for path in adjusted_paths]

    # prediction.csv
    df = pd.DataFrame({
        'id': final_paths,   
        'label': predictions
    })
    df.to_csv('naufala.2022.csv', index=False)
    print("Results saved to naufala.2022.csv")

# %%
if __name__ == "__main__":
    test_model()
# Out:
# Results saved to naufala.2022.csv
